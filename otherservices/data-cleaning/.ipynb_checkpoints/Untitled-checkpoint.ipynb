# %%
import pandas as pd
import numpy as np

# %%
originalFile=pd.read_excel("nutrition.xlsx",header=3)

# %%
columns=originalFile.columns
columns
# Out:
# Index(['ID', 'name', 'Food Group', 'Calories', 'Fat (g)', 'Protein (g)',
#        'Carbohydrate (g)', 'Sugars (g)', 'Fiber (g)', 'Cholesterol (mg)',
#        ...
#        'Serving Description 5 (g)', 'Serving Weight 6 (g)',
#        'Serving Description 6 (g)', 'Serving Weight 7 (g)',
#        'Serving Description 7 (g)', 'Serving Weight 8 (g)',
#        'Serving Description 8 (g)', 'Serving Weight 9 (g)',
#        'Serving Description 9 (g)', '200 Calorie Weight (g)'],
#       dtype='object', length=117)

# %%
len(columns)
# Out:
# 117

# %%
oFood=pd.read_csv("food.csv")

# %%
columns=oFood.columns
print(columns)
print("columns:",len(columns))
# Out:
# Index(['Category', 'Description', 'Nutrient Data Bank Number',
#        'Data.Alpha Carotene', 'Data.Ash', 'Data.Beta Carotene',
#        'Data.Beta Cryptoxanthin', 'Data.Carbohydrate', 'Data.Cholesterol',
#        'Data.Choline', 'Data.Fiber', 'Data.Kilocalories',
#        'Data.Lutein and Zeaxanthin', 'Data.Lycopene', 'Data.Manganese',
#        'Data.Niacin', 'Data.Pantothenic Acid', 'Data.Protein',
#        'Data.Refuse Percentage', 'Data.Retinol', 'Data.Riboflavin',
#        'Data.Selenium', 'Data.Sugar Total', 'Data.Thiamin', 'Data.Water',
#        'Data.Fat.Monosaturated Fat', 'Data.Fat.Polysaturated Fat',
#        'Data.Fat.Saturated Fat', 'Data.Fat.Total Lipid',
#        'Data.Household Weights.1st Household Weight',
#        'Data.Household Weights.1st Household Weight Description',
#        'Data.Household Weights.2nd Household Weight',
#        'Data.Household Weights.2nd Household Weight Description',
#        'Data.Major Minerals.Calcium', 'Data.Major Minerals.Copper',
# ...

# %%
#removing column Data.
new_columns=[]
for i in range(len(columns)):
    new_columns.append(columns[i].replace("ata.",""))
columns=[]
columns=new_columns.copy()
#removing column Vitamins.
new_columns=[]
for i in range(len(columns)):
    new_columns.append(columns[i].replace("vitamins.",""))
#removing column Vitamins.
columns=new_columns.copy()
new_columns=[]
columns
#removing column Fats.
new_columns=[]
for i in range(len(columns)):
    new_columns.append(columns[i].replace("fat.",""))
#removing column Fat
columns=new_columns.copy()
new_columns=[]

#removing column Mineral.
new_columns=[]
for i in range(len(columns)):
    new_columns.append(columns[i].replace("minerals.",""))
#removing column Fat
columns=new_columns.copy()
new_columns=[]
columns
#removing column majors
new_columns=[]
for i in range(len(columns)):
    new_columns.append(columns[i].replace("major ",""))
#removing column Fat
columns=new_columns.copy()
new_columns=[]
columns
#removing column space
for i in range(len(columns)):
    new_columns.append(columns[i].replace(" ",""))
#removing column Fat
columns=new_columns.copy()
new_columns=[]
columns
# def removeColumns(data,From,To):
#     new_columns=[]
#     for i in range(len(data)):
#         new_columns.append(data[i].replace(From,To))
#         return new_columns
# toBeRemoved=["Data.","Vitamins.","Fat.","Minerals.","Major "," "]
# for remove in toBeRemoved:
#     columns=removeColumns(columns,remove,"")
# columns
# Out:
# ['Category',
#  'Description',
#  'NutrientDataBankNumber',
#  'AlphaCarotene',
#  'Ash',
#  'BetaCarotene',
#  'BetaCryptoxanthin',
#  'Carbohydrate',
#  'Cholesterol',
#  'Choline',
#  'Fiber',
#  'Kilocalories',
#  'LuteinandZeaxanthin',
#  'Lycopene',
#  'Manganese',
#  'Niacin',
#  'PantothenicAcid',
#  'Protein',
#  'RefusePercentage',
#  'Retinol',
#  'Riboflavin',
#  'Selenium',
#  'SugarTotal',
#  'Thiamin',
#  'Water',
#  'MonosaturatedFat',
#  'PolysaturatedFat',
#  'SaturatedFat',
#  'TotalLipid',
#  'HouseholdWeights.1stHouseholdWeight',
#  'HouseholdWeights.1stHouseholdWeightDescription',
#  'HouseholdWeights.2ndHouseholdWeight',
#  'HouseholdWeights.2ndHouseholdWeightDescription',
#  'Calcium',
#  'Copper',
#  'Iron',
#  'Magnesium',
#  'Phosphorus',
#  'Potassium',
#  'Sodium',
#  'Zinc',
#  'VitaminA-IU',
#  'VitaminA-RAE',
#  'VitaminB12',
#  'VitaminB6',
#  'VitaminC',
#  'VitaminE',
#  'VitaminK']

# %%
oFood=pd.read_csv("food.csv",names=columns)

# %%
oFood=pd.read_csv("food.csv",header=0,names=columns)
oFood
# Out:
#         Category                 Description  NutrientDataBankNumber  \
# 0         BUTTER            BUTTER,WITH SALT                    1001
# 1         BUTTER    BUTTER,WHIPPED,WITH SALT                    1002
# 2     BUTTER OIL        BUTTER OIL,ANHYDROUS                    1003
# 3         CHEESE                 CHEESE,BLUE                    1004
# 4         CHEESE                CHEESE,BRICK                    1005
# ...          ...                         ...                     ...
# 7408   FROG LEGS               FROG LEGS,RAW                   80200
# 7409    MACKEREL             MACKEREL,SALTED                   83110
# 7410     SCALLOP  SCALLOP,(BAY&SEA),CKD,STMD                   90240
# 7411       SNAIL                   SNAIL,RAW                   90560
# 7412      TURTLE            TURTLE,GREEN,RAW                   93600
#
#       AlphaCarotene    Ash  BetaCarotene  BetaCryptoxanthin  Carbohydrate  \
# ...

# %%
oFood.drop("AlphaCarotene",axis=1,inplace=True)

# %%
oFood.drop(["Ash","NutrientDataBankNumber","BetaCarotene","BetaCryptoxanthin"],axis=1,inplace=True)

# %%
oFood.drop(["Choline","LuteinandZeaxanthin","Lycopene","Manganese"],axis=1,inplace=True)

# %%
oFood.drop(["PantothenicAcid","Niacin","Potassium","Sodium"],axis=1,inplace=True)

# %%
oFood.drop(["Retinol","Phosphorus","Magnesium","Zinc"],axis=1,inplace=True)

# %%
oFood.drop(["Riboflavin","Selenium","Calcium","Copper"],axis=1,inplace=True)

# %%
oFood.drop(["Thiamin","Iron","TotalLipid"],axis=1,inplace=True)

# %%
oFood.drop(["HouseholdWeights.2ndHouseholdWeightDescription","HouseholdWeights.1stHouseholdWeightDescription","Water"],axis=1,inplace=True)

# %%
oFood
# Out:
#         Category                 Description  Carbohydrate  Cholesterol  \
# 0         BUTTER            BUTTER,WITH SALT          0.06          215
# 1         BUTTER    BUTTER,WHIPPED,WITH SALT          0.06          219
# 2     BUTTER OIL        BUTTER OIL,ANHYDROUS          0.00          256
# 3         CHEESE                 CHEESE,BLUE          2.34           75
# 4         CHEESE                CHEESE,BRICK          2.79           94
# ...          ...                         ...           ...          ...
# 7408   FROG LEGS               FROG LEGS,RAW          0.00           50
# 7409    MACKEREL             MACKEREL,SALTED          0.00           95
# 7410     SCALLOP  SCALLOP,(BAY&SEA),CKD,STMD          0.00           53
# 7411       SNAIL                   SNAIL,RAW          2.00           50
# 7412      TURTLE            TURTLE,GREEN,RAW          0.00           50
#
#       Fiber  Kilocalories  Protein  RefusePercentage  SugarTotal  \
# ...

# %%
oFood.drop(["VitaminA-IU","VitaminA-RAE","VitaminB12","VitaminB6","VitaminC","VitaminE","VitaminK"],axis=1,inplace=True)

# %%
oFood["fat"]=oFood["PolysaturatedFat"]+oFood["MonosaturatedFat"]+oFood["SaturatedFat"]

# %%
oFood.drop(["MonosaturatedFat","PolysaturatedFat","SaturatedFat"],axis=1,inplace=True)

# %%
oFood[oFood["Category"]=="BUTTER"]=oFood[oFood["Category"]=="BUTTER"].drop([0,1,648,649])
oFood.dropna(inplace=True)

# %%
oFood[oFood["Category"]=="BUTTER"]
# Out:
#     Category          Description  Carbohydrate  Cholesterol  Fiber  \
# 133   BUTTER  BUTTER,WITHOUT SALT          0.06        215.0    0.0
#
#      Kilocalories  Protein  RefusePercentage  SugarTotal  \
# 133         717.0     0.85               0.0        0.06
#
#      HouseholdWeights.1stHouseholdWeight  HouseholdWeights.2ndHouseholdWeight  \
# 133                                227.0                                 14.0
#
#         fat
# 133  75.432

# %%
oFood
# Out:
#         Category                 Description  Carbohydrate  Cholesterol  \
# 2     BUTTER OIL        BUTTER OIL,ANHYDROUS          0.00        256.0
# 3         CHEESE                 CHEESE,BLUE          2.34         75.0
# 4         CHEESE                CHEESE,BRICK          2.79         94.0
# 5         CHEESE                 CHEESE,BRIE          0.45        100.0
# 6         CHEESE            CHEESE,CAMEMBERT          0.46         72.0
# ...          ...                         ...           ...          ...
# 7408   FROG LEGS               FROG LEGS,RAW          0.00         50.0
# 7409    MACKEREL             MACKEREL,SALTED          0.00         95.0
# 7410     SCALLOP  SCALLOP,(BAY&SEA),CKD,STMD          0.00         53.0
# 7411       SNAIL                   SNAIL,RAW          2.00         50.0
# 7412      TURTLE            TURTLE,GREEN,RAW          0.00         50.0
#
#       Fiber  Kilocalories  Protein  RefusePercentage  SugarTotal  \
# ...

# %%
indexes=np.array(oFood[oFood["Category"].str.contains(r"BUTTER").fillna(False)].index)
indexes=np.delete(indexes,1,0)   
oFood[oFood["Category"].str.contains(r"BUTTER").fillna(False)]=oFood[oFood["Category"].str.contains(r"BUTTER").fillna(False)].drop(indexes)
oFood[oFood["Category"].str.contains(r"BUTTER").fillna(False)]
# Out:
#     Category          Description  Carbohydrate  Cholesterol  Fiber  \
# 133   BUTTER  BUTTER,WITHOUT SALT          0.06        215.0    0.0
#
#      Kilocalories  Protein  RefusePercentage  SugarTotal  \
# 133         717.0     0.85               0.0        0.06
#
#      HouseholdWeights.1stHouseholdWeight  HouseholdWeights.2ndHouseholdWeight  \
# 133                                227.0                                 14.0
#
#         fat
# 133  75.432

# %%
oFood.dropna(inplace=True)

# %%
oFood
# Out:
#        Category                 Description  Carbohydrate  Cholesterol  Fiber  \
# 3        CHEESE                 CHEESE,BLUE          2.34         75.0    0.0
# 4        CHEESE                CHEESE,BRICK          2.79         94.0    0.0
# 5        CHEESE                 CHEESE,BRIE          0.45        100.0    0.0
# 6        CHEESE            CHEESE,CAMEMBERT          0.46         72.0    0.0
# 7        CHEESE              CHEESE,CARAWAY          3.06         93.0    0.0
# ...         ...                         ...           ...          ...    ...
# 7408  FROG LEGS               FROG LEGS,RAW          0.00         50.0    0.0
# 7409   MACKEREL             MACKEREL,SALTED          0.00         95.0    0.0
# 7410    SCALLOP  SCALLOP,(BAY&SEA),CKD,STMD          0.00         53.0    0.0
# 7411      SNAIL                   SNAIL,RAW          2.00         50.0    0.0
# 7412     TURTLE            TURTLE,GREEN,RAW          0.00         50.0    0.0
#
# ...

# %%
indexes=np.array(oFood[oFood["Category"].str.contains(r"CHEESE").fillna(False)].index)
indexes=np.delete(indexes,5,0)
oFood[oFood["Category"].str.contains(r"CHEESE").fillna(False)]=oFood[oFood["Category"].str.contains(r"CHEESE").fillna(False)].drop(indexes)
oFood[oFood["Category"].str.contains(r"CHEESE").fillna(False)]
oFood.dropna(inplace=True)

# %%
remove=r"CREAM"
delIndex=49
indexes=np.array(oFood[oFood["Category"].str.contains(remove).fillna(False)].index)
indexes=np.delete(indexes,delIndex,0)
oFood[oFood["Category"].str.contains(remove).fillna(False)]=oFood[oFood["Category"].str.contains(remove).fillna(False)].drop(indexes)
oFood[oFood["Category"].str.contains(remove).fillna(False)]
oFood.dropna(inplace=True)

# %%
remove=r"MILK"
delIndex=31
indexes=np.array(oFood[oFood["Category"].str.contains(remove).fillna(False)].index)
indexes=np.delete(indexes,delIndex,0)
oFood[oFood["Category"].str.contains(remove).fillna(False)]=oFood[oFood["Category"].str.contains(remove).fillna(False)].drop(indexes)
oFood[oFood["Category"].str.contains(remove).fillna(False)]
oFood.dropna(inplace=True)

# %%
remove=r"No Category"
#delIndex=31
indexes=np.array(oFood[oFood["Category"].str.contains(remove).fillna(False)].index)
#indexes=np.delete(indexes,delIndex,0)
oFood[oFood["Category"].str.contains(remove).fillna(False)]=oFood[oFood["Category"].str.contains(remove).fillna(False)].drop(indexes)
oFood[oFood["Category"].str.contains(remove).fillna(False)]
oFood.dropna(inplace=True)

# %%
remove=r"DESSERT"
#delIndex=31
indexes=np.array(oFood[oFood["Category"].str.contains(remove).fillna(False)].index)
#indexes=np.delete(indexes,delIndex,0)
oFood[oFood["Category"].str.contains(remove).fillna(False)]=oFood[oFood["Category"].str.contains(remove).fillna(False)].drop(indexes)
oFood[oFood["Category"].str.contains(remove).fillna(False)]
oFood.dropna(inplace=True)

# %%
remove=r"YOGURT"
delIndex=0
indexes=np.array(oFood[oFood["Category"].str.contains(remove).fillna(False)].index)
indexes=np.delete(indexes,delIndex,0)
oFood[oFood["Category"].str.contains(remove).fillna(False)]=oFood[oFood["Category"].str.contains(remove).fillna(False)].drop(indexes)
oFood[oFood["Category"].str.contains(remove).fillna(False)]
oFood.dropna(inplace=True)

# %%
remove=r"WHEY"
delIndex=0
indexes=np.array(oFood[oFood["Category"].str.contains(remove).fillna(False)].index)
#indexes=np.delete(indexes,delIndex,0)
oFood[oFood["Category"].str.contains(remove).fillna(False)]=oFood[oFood["Category"].str.contains(remove).fillna(False)].drop(indexes)
oFood[oFood["Category"].str.contains(remove).fillna(False)]
oFood.dropna(inplace=True)

# %%
oFood[oFood["Category"].str.contains("EGG").fillna(False)]

remove=r"EGG"
delIndex=[0,1,2]
indexes=np.array(oFood[oFood["Category"].str.contains(remove).fillna(False)].index)
indexes=np.delete(indexes,delIndex,0)
oFood[oFood["Category"].str.contains(remove).fillna(False)]=oFood[oFood["Category"].str.contains(remove).fillna(False)].drop(indexes)
oFood[oFood["Category"].str.contains(remove).fillna(False)]
oFood.dropna(inplace=True)

# %%
oFood[oFood["Category"].str.contains("EGG").fillna(False)]
# Out:
#     Category          Description  Carbohydrate  Cholesterol  Fiber  \
# 111      EGG  EGG,WHOLE,RAW,FRESH          0.77        423.0    0.0
# 112      EGG  EGG,WHITE,RAW,FRESH          0.73          0.0    0.0
# 113      EGG    EGG,YOLK,RAW,FRSH          3.59       1234.0    0.0
#
#      Kilocalories  Protein  RefusePercentage  SugarTotal  \
# 111         143.0    12.58              12.0        0.77
# 112          48.0    10.90               0.0        0.71
# 113         317.0    15.86               0.0        0.56
#
#      HouseholdWeights.1stHouseholdWeight  HouseholdWeights.2ndHouseholdWeight  \
# 111                                243.0                                 56.0
# 112                                243.0                                 33.0
# 113                                243.0                                 17.0
#
#         fat
# 111   8.273
# 112   0.000
# 113  25.493

# %%
oFood.to_csv("saveState.csv",index=False)

# %%
newFile=pd.read_csv("saveState.csv")

# %%
newFile
# Out:
#         Category                                        Description  \
# 0         CHEESE                                     CHEESE,CHEDDAR
# 1     SOUR DRSNG  SOUR DRSNG,NON-BUTTERFAT,CULTURED,FILLED CREAM...
# 2       SOUR CRM                            SOUR CRM,IMITN,CULTURED
# 3           MILK                          MILK,INDIAN BUFFALO,FLUID
# 4         YOGURT          YOGURT,PLN,WHL MILK,8 GRAMS PROT PER 8 OZ
# ...          ...                                                ...
# 6887   FROG LEGS                                      FROG LEGS,RAW
# 6888    MACKEREL                                    MACKEREL,SALTED
# 6889     SCALLOP                         SCALLOP,(BAY&SEA),CKD,STMD
# 6890       SNAIL                                          SNAIL,RAW
# 6891      TURTLE                                   TURTLE,GREEN,RAW
#
#       Carbohydrate  Cholesterol  Fiber  Kilocalories  Protein  \
# 0             1.28        105.0    0.0         403.0    24.90
# ...
