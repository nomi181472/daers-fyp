# %%
import pandas as pd

# %%
columns=['ID', 'Muscle Group', 'exerciseName', 'Level', 'type', 'direction', 'modality',
       'joint']
originalFile=pd.read_excel("resist_train_planner.xls",header=18,names=columns)

# %%
originalFile
# Out:
#      ID        Muscle Group            exerciseName     Level  U/L/C P / P  \
# 0   NaN  Abdominals - Lower     Full Reverse Crunch  Advanced   Core  Push
# 1   NaN  Abdominals - Lower      Incline Hip Thrust  Advanced   Core  Push
# 2   NaN  Abdominals - Lower  Incline Reverse Crunch  Advanced   Core  Push
# 3   NaN  Abdominals - Lower        Lying Hip Thrust  Advanced   Core  Push
# 4   NaN  Abdominals - Lower          Reverse Crunch  Beginner   Core  Push
# ..   ..                 ...                     ...       ...    ...   ...
# 265 NaN             Triceps  Towel Triceps Pushdown  Beginner  Upper  Push
# 266 NaN             Triceps       Tricep Extensions  Beginner  Upper  Push
# 267 NaN             Triceps         Tricep Pushdown  Beginner  Upper  Push
# 268 NaN             Triceps         Tricep Pushdown  Beginner  Upper  Push
# 269 NaN             Triceps   V-Bar Tricep Pushdown  Beginner  Upper  Push
#
#     Modality Joint
# 0         FW     M
# 1         FW     M
# ...

# %%
# Out:
# ['ID',
#  'Muscle Group',
#  'exerciseName',
#  'Level',
#  'U/L/C',
#  'P / P',
#  'Modality',
#  'Joint']
